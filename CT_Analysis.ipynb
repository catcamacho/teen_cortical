# %%
# Import modules


# Set up study specific variables

# %%
######### File handling #########

# %%
######### Analysis functions #########

# %%
######### Graphing functions #########

# %%
######### Nodes #########

# %%
######### Workflow #########
